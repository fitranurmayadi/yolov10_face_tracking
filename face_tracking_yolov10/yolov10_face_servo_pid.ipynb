# %% [markdown]
# #Face Detection yolov10

# %%
import cv2
import time
import psutil
import GPUtil
from ultralytics import YOLOv10

# Muat model YOLOv8
model = YOLOv10('../yolov10s-face.pt')  # model YOLOv10 yang dilatih untuk deteksi wajah

# Inisialisasi kamera (biasanya 0 adalah kamera default, Anda mungkin perlu mengubahnya jika ada beberapa kamera)
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    print("Error: Tidak dapat membuka kamera.")
    exit()
# Set resolusi kamera ke 1280x720
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Variabel untuk menghitung FPS
prev_time = 0

# Fungsi untuk mendapatkan penggunaan GPU
def get_gpu_usage():
    gpus = GPUtil.getGPUs()
    if gpus:
        gpu = gpus[0]
        return gpu.load * 100  # Mengembalikan penggunaan GPU dalam persentase
    return 0


while True:
    # Baca frame dari kamera
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Tidak dapat membaca frame dari kamera.")
        break
    
    # Deteksi wajah menggunakan YOLOv10
    results = model(frame)[0]

    # Proses hasil deteksi
    for result in results:
        boxes = result.boxes  # Akses bounding box dari hasil deteksi
        for box in boxes:
            # Dapatkan koordinat bounding box dan konversi ke integer
            x_min, y_min, x_max, y_max = map(int, box.xyxy[0])
            conf = box.conf.item()  # Dapatkan confidence score

            # Gambar persegi panjang di sekitar wajah yang terdeteksi
            cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 0, 0), 2)
            
            # Hitung titik tengah bounding box
            center_x = (x_min + x_max) // 2
            center_y = (y_min + y_max) // 2
            
            # Tampilkan informasi bounding box dan titik tengah
            debug_text = f"Box: ({x_min}, {y_min}), W: {x_max-x_min}, H: {y_max-y_min}, Center: ({center_x}, {center_y})"
            #print(debug_text)  # Tampilkan di console/serial monitor
            
            # Tampilkan informasi pada frame
            cv2.putText(frame, debug_text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
            cv2.circle(frame, (center_x, center_y), 5, (0, 255, 0), -1)
    
    # Dapatkan waktu sekarang
    curr_time = time.time()
    exec_time = curr_time - prev_time
    prev_time = curr_time
    fps = 1 / exec_time
    
    # Dapatkan penggunaan CPU dan GPU
    cpu_usage = psutil.cpu_percent()
    gpu_usage = get_gpu_usage()
    
    # Tambahkan teks ke frame
    cv2.putText(frame, 'Face Tracking Yolov10', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'CPU Usage: {cpu_usage}%', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'GPU Usage: {gpu_usage:.1f}%', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'FPS: {fps:.2f}', (10, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
   
    # Tampilkan frame dengan wajah yang terdeteksi dan data debug
    cv2.imshow('Face Detection', frame)
    
    # Tekan 'q' untuk keluar dari loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan setelah selesai
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 90.5ms
# Speed: 8.0ms preprocess, 90.5ms inference, 111.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 31.3ms
# Speed: 2.0ms preprocess, 31.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 32.1ms
# Speed: 2.0ms preprocess, 32.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 33.3ms
# Speed: 2.0ms preprocess, 33.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 29.0ms
# Speed: 2.0ms preprocess, 29.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 30.5ms
# Speed: 2.0ms preprocess, 30.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 29.5ms
# Speed: 2.0ms preprocess, 29.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 28.5ms
# Speed: 1.0ms preprocess, 28.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 31.5ms
# Speed: 2.0ms preprocess, 31.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ##Tracking with yolov10

# %%
import cv2
import time
import psutil
import GPUtil
from ultralytics import YOLOv10
import serial

# Sesuaikan dengan port serial yang terhubung ke Arduino Anda
#serial_port = '/dev/ttyUSB0'  # Contoh untuk Linux
serial_port = 'COM9'  # Contoh untuk Windows
baud_rate = 9600  # Sesuaikan dengan baud rate pada program Arduino

# Inisialisasi koneksi serial
ser = serial.Serial(serial_port, baud_rate, timeout=1)

# Fungsi untuk mengirim data sudut ke Arduino
def send_servo_angles(angleX, angleY):
    if 0 <= angleX <= 180 and 0 <= angleY <= 180:
        command = f"x={angleX} y={angleY}\n"
        ser.write(command.encode())
        print(f"Sent: {command.strip()}")
    else:
        print("Invalid angle. Please enter values between 0 and 180.")

# Fungsi PID Controller
class PID:
    def __init__(self, Kp, Ki, Kd, setpoint=0):
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.setpoint = setpoint
        self.prev_error_x = 0
        self.prev_error_y = 0
        self.integral_x = 0
        self.integral_y = 0

    def compute(self, x, y, frame_width=1280, frame_height=720):
        error_x = self.calculate_error(x, 600, 680, frame_width, 32)
        error_y = self.calculate_error(y, 320, 400, frame_height, 18)

        # Compute integral and derivative for x
        self.integral_x += error_x
        derivative_x = error_x - self.prev_error_x

        # Compute integral and derivative for y
        self.integral_y += error_y
        derivative_y = error_y - self.prev_error_y

        # Compute output
        output_x = self.Kp * error_x + self.Ki * self.integral_x + self.Kd * derivative_x
        output_y = self.Kp * error_y + self.Ki * self.integral_y + self.Kd * derivative_y

        # Update previous errors
        self.prev_error_x = error_x
        self.prev_error_y = error_y

        return output_x, output_y

    def calculate_error(self, value, lower_bound, upper_bound, frame_size, divisions):
        division_size = frame_size // divisions
        center = (lower_bound + upper_bound) // 2

        # Error is 0 if within the bounds
        if lower_bound <= value <= upper_bound:
            return 0

        # Calculate error based on which division the value falls into
        for i in range(1, (divisions // 2) + 1):
            if center - i * division_size <= value < center - (i - 1) * division_size:
                return -i
            elif center + (i - 1) * division_size < value <= center + i * division_size:
                return i
        return 0  # Default error if out of expected range


# Muat model YOLOv10
model = YOLOv10('../yolov10s-face.pt', verbose=False)  # Pastikan Anda memiliki model YOLOv10 yang dilatih untuk deteksi wajah

# Inisialisasi kamera (biasanya 0 adalah kamera default, Anda mungkin perlu mengubahnya jika ada beberapa kamera)
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    print("Error: Tidak dapat membuka kamera.")
    exit()

# Set resolusi kamera ke 1280x720
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Variabel untuk menghitung FPS
prev_time = 0

# Fungsi untuk mendapatkan penggunaan GPU
def get_gpu_usage():
    gpus = GPUtil.getGPUs()
    if gpus:
        gpu = gpus[0]
        return gpu.load * 100  # Mengembalikan penggunaan GPU dalam persentase
    return 0

# Inisialisasi sudut servo awal
setpoint_servo_x = 90
setpoint_servo_y = 90
send_servo_angles(setpoint_servo_x, setpoint_servo_y)  # Set sudut awal

# Inisialisasi PID Controller
pid = PID(Kp=0.5, Ki=0.1, Kd=0.01)


while True:
    # Baca frame dari kamera
    ret, frame = cap.read()
    frame = cv2.resize(frame, (1280, 720))
    
    if not ret:
        print("Error: Tidak dapat membaca frame dari kamera.")
        break
    
    # Deteksi wajah menggunakan YOLOv10
    results = model(frame)[0]

    # Proses hasil deteksi
    if results:
        for result in results:
            boxes = result.boxes  # Akses bounding box dari hasil deteksi
            if boxes:
                for box in boxes:
                    # Dapatkan koordinat bounding box dan konversi ke integer
                    x_min, y_min, x_max, y_max = map(int, box.xyxy[0])
                    conf = box.conf.item()  # Dapatkan confidence score

                    # Gambar persegi panjang di sekitar wajah yang terdeteksi
                    cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0,165,255), 2)
                    
                    # Hitung titik tengah bounding box
                    center_x = (x_min + x_max) // 2
                    center_y = (y_min + y_max) // 2

                    # Hitung titik tengah frame
                    frame_center_x = frame.shape[1] // 2
                    frame_center_y = frame.shape[0] // 2
                    
                    # Hitung output PID
                    pid_output_x, pid_output_y = pid.compute(center_x, center_y)

                    # Update sudut servo berdasarkan output PID
                    servo_angle_x = setpoint_servo_x  - pid_output_x
                    servo_angle_y = setpoint_servo_y  - pid_output_y
                    # Kirim sudut servo ke Arduino
                    send_servo_angles(servo_angle_x, servo_angle_y)
                    #print()
                    # Tampilkan informasi bounding box dan titik tengah
                    debug_text = f"Center: ({center_x}, {center_y}), Servo : ({servo_angle_x}, {servo_angle_y}), PID : ({pid_output_x}, {pid_output_y})"
                    print(debug_text)  # Tampilkan di console/serial monitor
                    
                    # Tampilkan informasi pada frame
                    cv2.putText(frame, debug_text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,165,255), 1, cv2.LINE_AA)
                    cv2.circle(frame, (center_x, center_y), 5, (0, 165, 255), -1)

                    cv2.rectangle(frame, (600, 320), (680, 400), (0, 0, 255), 2)
                    cv2.circle(frame, (frame_center_x, frame_center_y), 5, (0, 0, 255), -1)

    
    # Dapatkan waktu sekarang
    curr_time = time.time()
    exec_time = curr_time - prev_time
    prev_time = curr_time
    fps = 1 / exec_time
    
    # Dapatkan penggunaan CPU dan GPU
    cpu_usage = psutil.cpu_percent()
    gpu_usage = get_gpu_usage()
    
    # Tambahkan teks ke frame
    cv2.putText(frame, 'Face Tracking Yolov10', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'CPU Usage: {cpu_usage}%', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'GPU Usage: {gpu_usage:.1f}%', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'FPS: {fps:.2f}', (10, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)

    # Tampilkan frame dengan wajah yang terdeteksi dan data debug
    cv2.imshow('Face Detection', frame)
    
    # Tekan 'q' untuk keluar dari loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan setelah selesai
cap.release()
cv2.destroyAllWindows()
ser.close()
# Out:
# Sent: x=90 y=90
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 3.0ms preprocess, 40.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.27 y=94.88
# Center: (385, 72), Servo : (94.27, 94.88), PID : (-4.2700000000000005, -4.88)
#
# 0: 384x640 2 faces, 40.5ms
# Speed: 2.0ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.9 y=94.99
# Center: (391, 107), Servo : (94.9, 94.99), PID : (-4.9, -4.99)
# Sent: x=95.6 y=95.7
# Center: (392, 110), Servo : (95.6, 95.7), PID : (-5.6, -5.7)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 5.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.08 y=95.79
# Center: (458, 153), Servo : (95.08, 95.79), PID : (-5.08, -5.790000000000001)
#
# 0: 384x640 1 face, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.38 y=95.79
# Center: (520, 187), Servo : (94.38, 95.79), PID : (-4.380000000000001, -5.790000000000001)
#
# 0: 384x640 1 face, 34.5ms
# Speed: 4.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.09 y=96.3
# Center: (587, 198), Servo : (94.09, 96.3), PID : (-4.09, -6.300000000000001)
#
# 0: 384x640 1 face, 40.0ms
# Speed: 4.0ms preprocess, 40.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.3 y=96.8
# Center: (592, 192), Servo : (94.3, 96.8), PID : (-4.300000000000001, -6.8)
#
# 0: 384x640 1 face, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.5 y=97.3
# Center: (588, 189), Servo : (94.5, 97.3), PID : (-4.5, -7.300000000000001)
#
# 0: 384x640 1 face, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.7 y=97.8
# Center: (576, 166), Servo : (94.7, 97.8), PID : (-4.7, -7.800000000000001)
#
# 0: 384x640 1 face, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.9 y=98.91
# Center: (567, 154), Servo : (94.9, 98.91), PID : (-4.9, -8.91)
#
# 0: 384x640 1 face, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.1 y=99.5
# Center: (564, 152), Servo : (95.1, 99.5), PID : (-5.1000000000000005, -9.5)
#
# 0: 384x640 1 face, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.3 y=100.1
# Center: (560, 157), Servo : (95.3, 100.1), PID : (-5.3, -10.100000000000001)
#
# 0: 384x640 1 face, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.5 y=100.09
# Center: (562, 164), Servo : (95.5, 100.09), PID : (-5.5, -10.090000000000002)
#
# 0: 384x640 1 face, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.7 y=100.6
# Center: (564, 184), Servo : (95.7, 100.6), PID : (-5.7, -10.6)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.9 y=101.1
# Center: (566, 184), Servo : (95.9, 101.1), PID : (-5.9, -11.1)
#
# 0: 384x640 1 face, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.1 y=101.6
# Center: (567, 184), Servo : (96.1, 101.6), PID : (-6.1000000000000005, -11.6)
#
# 0: 384x640 1 face, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.3 y=102.1
# Center: (567, 191), Servo : (96.3, 102.1), PID : (-6.300000000000001, -12.100000000000001)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 2.6ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.5 y=102.6
# Center: (576, 191), Servo : (96.5, 102.6), PID : (-6.5, -12.600000000000001)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.7 y=102.49
# Center: (576, 202), Servo : (96.7, 102.49), PID : (-6.7, -12.49)
#
# 0: 384x640 1 face, 39.1ms
# Speed: 4.0ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.9 y=102.9
# Center: (575, 203), Servo : (96.9, 102.9), PID : (-6.9, -12.9)
#
# 0: 384x640 1 face, 38.2ms
# Speed: 3.0ms preprocess, 38.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.1 y=103.3
# Center: (574, 203), Servo : (97.1, 103.3), PID : (-7.1000000000000005, -13.3)
#
# 0: 384x640 1 face, 41.5ms
# Speed: 2.0ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=103.7
# Center: (574, 204), Servo : (97.3, 103.7), PID : (-7.300000000000001, -13.700000000000001)
#
# 0: 384x640 1 face, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.5 y=104.1
# Center: (586, 212), Servo : (97.5, 104.1), PID : (-7.5, -14.100000000000001)
#
# 0: 384x640 1 face, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.7 y=104.5
# Center: (580, 213), Servo : (97.7, 104.5), PID : (-7.7, -14.5)
#
# 0: 384x640 1 face, 41.5ms
# Speed: 4.0ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.9 y=104.9
# Center: (596, 232), Servo : (97.9, 104.9), PID : (-7.9, -14.9)
#
# 0: 384x640 1 face, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.1 y=105.3
# Center: (597, 237), Servo : (98.1, 105.3), PID : (-8.100000000000001, -15.3)
#
# 0: 384x640 1 face, 37.0ms
# Speed: 3.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.3 y=105.7
# Center: (596, 237), Servo : (98.3, 105.7), PID : (-8.3, -15.700000000000001)
#
# 0: 384x640 1 face, 38.0ms
# Speed: 3.5ms preprocess, 38.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.28 y=106.1
# Center: (605, 224), Servo : (97.28, 106.1), PID : (-7.280000000000001, -16.1)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 4.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=105.89
# Center: (611, 240), Servo : (97.3, 105.89), PID : (-7.300000000000001, -15.89)
#
# 0: 384x640 1 face, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=106.81
# Center: (618, 226), Servo : (97.3, 106.81), PID : (-7.300000000000001, -16.810000000000002)
#
# 0: 384x640 1 face, 40.0ms
# Speed: 4.0ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=106.59
# Center: (623, 247), Servo : (97.3, 106.59), PID : (-7.300000000000001, -16.59)
#
# 0: 384x640 1 face, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=106.9
# Center: (623, 262), Servo : (97.3, 106.9), PID : (-7.300000000000001, -16.9)
#
# 0: 384x640 1 face, 36.9ms
# Speed: 3.0ms preprocess, 36.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=107.2
# Center: (622, 261), Servo : (97.3, 107.2), PID : (-7.300000000000001, -17.200000000000003)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=107.5
# Center: (621, 262), Servo : (97.3, 107.5), PID : (-7.300000000000001, -17.5)
#
# 0: 384x640 1 face, 30.5ms
# Speed: 2.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=107.19
# Center: (620, 280), Servo : (97.3, 107.19), PID : (-7.300000000000001, -17.189999999999998)
#
# 0: 384x640 1 face, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=107.4
# Center: (621, 280), Servo : (97.3, 107.4), PID : (-7.300000000000001, -17.400000000000002)
#
# 0: 384x640 1 face, 37.4ms
# Speed: 3.0ms preprocess, 37.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.21000000000001
# Center: (621, 278), Servo : (97.3, 108.21000000000001), PID : (-7.300000000000001, -18.21)
#
# 0: 384x640 1 face, 35.2ms
# Speed: 2.0ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.5
# Center: (624, 273), Servo : (97.3, 108.5), PID : (-7.300000000000001, -18.5)
#
# 0: 384x640 1 face, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.19
# Center: (624, 293), Servo : (97.3, 108.19), PID : (-7.300000000000001, -18.189999999999998)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 5.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (630, 299), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 4.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (623, 280), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 38.5ms
# Speed: 3.0ms preprocess, 38.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.8
# Center: (624, 296), Servo : (97.3, 108.8), PID : (-7.300000000000001, -18.8)
#
# 0: 384x640 1 face, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=109.0
# Center: (622, 295), Servo : (97.3, 109.0), PID : (-7.300000000000001, -19.0)
#
# 0: 384x640 1 face, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=109.2
# Center: (619, 289), Servo : (97.3, 109.2), PID : (-7.300000000000001, -19.2)
#
# 0: 384x640 1 face, 34.5ms
# Speed: 4.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=109.4
# Center: (618, 305), Servo : (97.3, 109.4), PID : (-7.300000000000001, -19.400000000000002)
#
# 0: 384x640 1 face, 37.0ms
# Speed: 5.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.38
# Center: (619, 321), Servo : (97.3, 108.38), PID : (-7.300000000000001, -18.380000000000003)
#
# 0: 384x640 1 face, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (619, 325), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 37.9ms
# Speed: 2.6ms preprocess, 37.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (620, 328), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (620, 326), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (621, 327), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 38.5ms
# Speed: 6.0ms preprocess, 38.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (620, 326), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (613, 323), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 37.2ms
# Speed: 3.0ms preprocess, 37.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (611, 322), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.4
# Center: (609, 320), Servo : (97.3, 108.4), PID : (-7.300000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=109.62
# Center: (610, 319), Servo : (97.3, 109.62), PID : (-7.300000000000001, -19.62)
#
# 0: 384x640 1 face, 30.0ms
# Speed: 1.9ms preprocess, 30.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.58
# Center: (610, 321), Servo : (97.3, 108.58), PID : (-7.300000000000001, -18.580000000000002)
#
# 0: 384x640 1 face, 30.0ms
# Speed: 3.0ms preprocess, 30.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (613, 322), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (616, 326), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 29.6ms
# Speed: 3.1ms preprocess, 29.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (618, 329), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 32.0ms
# Speed: 2.0ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (621, 332), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 30.0ms
# Speed: 4.0ms preprocess, 30.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (623, 332), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (621, 331), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 30.0ms
# Speed: 4.5ms preprocess, 30.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (623, 326), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (621, 323), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)
#
# 0: 384x640 1 face, 32.2ms
# Speed: 2.0ms preprocess, 32.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.3 y=108.6
# Center: (619, 324), Servo : (97.3, 108.6), PID : (-7.300000000000001, -18.6)

# %% [markdown]
# #Tracking with yolov8

# %%
import cv2
import time
import psutil
import GPUtil
from ultralytics import YOLO
import serial

# Sesuaikan dengan port serial yang terhubung ke Arduino Anda
#serial_port = '/dev/ttyUSB0'  # Contoh untuk Linux
serial_port = 'COM9'  # Contoh untuk Windows
baud_rate = 9600  # Sesuaikan dengan baud rate pada program Arduino

# Inisialisasi koneksi serial
ser = serial.Serial(serial_port, baud_rate, timeout=1)

# Fungsi untuk mengirim data sudut ke Arduino
def send_servo_angles(angleX, angleY):
    if 0 <= angleX <= 180 and 0 <= angleY <= 180:
        command = f"x={angleX} y={angleY}\n"
        ser.write(command.encode())
        print(f"Sent: {command.strip()}")
    else:
        print("Invalid angle. Please enter values between 0 and 180.")

# Fungsi PID Controller
class PID:
    def __init__(self, Kp, Ki, Kd, setpoint=0):
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.setpoint = setpoint
        self.prev_error_x = 0
        self.prev_error_y = 0
        self.integral_x = 0
        self.integral_y = 0

    def compute(self, x, y, frame_width=1280, frame_height=720):
        error_x = self.calculate_error(x, 600, 680, frame_width, 32)
        error_y = self.calculate_error(y, 320, 400, frame_height, 18)

        # Compute integral and derivative for x
        self.integral_x += error_x
        derivative_x = error_x - self.prev_error_x

        # Compute integral and derivative for y
        self.integral_y += error_y
        derivative_y = error_y - self.prev_error_y

        # Compute output
        output_x = self.Kp * error_x + self.Ki * self.integral_x + self.Kd * derivative_x
        output_y = self.Kp * error_y + self.Ki * self.integral_y + self.Kd * derivative_y

        # Update previous errors
        self.prev_error_x = error_x
        self.prev_error_y = error_y

        return output_x, output_y

    def calculate_error(self, value, lower_bound, upper_bound, frame_size, divisions):
        division_size = frame_size // divisions
        center = (lower_bound + upper_bound) // 2

        # Error is 0 if within the bounds
        if lower_bound <= value <= upper_bound:
            return 0

        # Calculate error based on which division the value falls into
        for i in range(1, (divisions // 2) + 1):
            if center - i * division_size <= value < center - (i - 1) * division_size:
                return -i
            elif center + (i - 1) * division_size < value <= center + i * division_size:
                return i
        return 0  # Default error if out of expected range


# Muat model YOLOv8
model = YOLO('../yolov8n-face.pt', verbose=False)  # Pastikan Anda memiliki model YOLOv8 yang dilatih untuk deteksi wajah

# Inisialisasi kamera (biasanya 0 adalah kamera default, Anda mungkin perlu mengubahnya jika ada beberapa kamera)
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    print("Error: Tidak dapat membuka kamera.")
    exit()

# Set resolusi kamera ke 1280x720
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# Variabel untuk menghitung FPS
prev_time = 0

# Fungsi untuk mendapatkan penggunaan GPU
def get_gpu_usage():
    gpus = GPUtil.getGPUs()
    if gpus:
        gpu = gpus[0]
        return gpu.load * 100  # Mengembalikan penggunaan GPU dalam persentase
    return 0


# Inisialisasi sudut servo awal
setpoint_servo_x = 90
setpoint_servo_y = 90
send_servo_angles(setpoint_servo_x, setpoint_servo_y)  # Set sudut awal

# Inisialisasi PID Controller
pid = PID(Kp=0.5, Ki=0.2, Kd=0.2)

while True:
    # Baca frame dari kamera
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Tidak dapat membaca frame dari kamera.")
        break
    
    # Deteksi wajah menggunakan YOLOv8
    results = model(frame)

    # Proses hasil deteksi
    if results:
        for result in results:
            boxes = result.boxes  # Akses bounding box dari hasil deteksi
            if boxes:
                for box in boxes:
                    # Dapatkan koordinat bounding box dan konversi ke integer
                    x_min, y_min, x_max, y_max = map(int, box.xyxy[0])
                    conf = box.conf.item()  # Dapatkan confidence score

                    # Gambar persegi panjang di sekitar wajah yang terdeteksi
                    cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 165, 255), 2)
                    
                    # Hitung titik tengah bounding box
                    center_x = (x_min + x_max) // 2
                    center_y = (y_min + y_max) // 2

                    # Hitung titik tengah frame
                    frame_center_x = frame.shape[1] // 2
                    frame_center_y = frame.shape[0] // 2
                    
                    # Hitung output PID
                    pid_output_x, pid_output_y = pid.compute(center_x, center_y)

                    # Update sudut servo berdasarkan output PID
                    servo_angle_x = setpoint_servo_x  - pid_output_x
                    servo_angle_y = setpoint_servo_y  - pid_output_y
                    # Kirim sudut servo ke Arduino
                    send_servo_angles(servo_angle_x, servo_angle_y)
                    #print()
                    # Tampilkan informasi bounding box dan titik tengah
                    debug_text = f"Center: ({center_x}, {center_y}), Servo : ({servo_angle_x}, {servo_angle_y}), PID : ({pid_output_x}, {pid_output_y})"
                    print(debug_text)  # Tampilkan di console/serial monitor
                    
                    # Tampilkan informasi pada frame
                    cv2.putText(frame, debug_text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,165,255), 1, cv2.LINE_AA)
                    cv2.circle(frame, (center_x, center_y), 5, (0, 165, 255), -1)

                    cv2.rectangle(frame, (600, 320), (680, 400), (0, 0, 255), 2)
                    cv2.circle(frame, (frame_center_x, frame_center_y), 5, (0, 0, 255), -1)


    
    # Dapatkan waktu sekarang
    curr_time = time.time()
    exec_time = curr_time - prev_time
    prev_time = curr_time
    fps = 1 / exec_time
    
    # Dapatkan penggunaan CPU dan GPU
    cpu_usage = psutil.cpu_percent()
    gpu_usage = get_gpu_usage()
    
    # Tambahkan teks ke frame
    cv2.putText(frame, 'Face Tracking Yolov8', (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'CPU Usage: {cpu_usage}%', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'GPU Usage: {gpu_usage:.1f}%', (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(frame, f'FPS: {fps:.2f}', (10, 80), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1, cv2.LINE_AA)
    
    # Tampilkan frame dengan wajah yang terdeteksi dan data debug
    cv2.imshow('Face Detection', frame)
    
    # Tekan 'q' untuk keluar dari loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan setelah selesai
cap.release()
cv2.destroyAllWindows()
ser.close()
# Out:
# Sent: x=90 y=90
#
# 0: 384x640 (no detections), 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 5.0ms preprocess, 25.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 4.0ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 2.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 3.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 3.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.7ms
# Speed: 3.0ms preprocess, 37.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.0ms
# Speed: 3.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 3.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 3.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 5.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 3.0ms preprocess, 41.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 2.9ms preprocess, 50.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.0ms
# Speed: 4.0ms preprocess, 65.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.6ms
# Speed: 7.0ms preprocess, 85.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 3.5ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 3.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 56.5ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.5 y=96.3
# Center: (447, 95), Servo : (94.5, 96.3), PID : (-4.5, -6.300000000000001)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.4 y=95.4
# Center: (410, 124), Servo : (95.4, 95.4), PID : (-5.4, -5.3999999999999995)
#
# 0: 384x640 1 face, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.5 y=95.9
# Center: (472, 175), Servo : (95.5, 95.9), PID : (-5.5, -5.8999999999999995)
#
# 0: 384x640 1 face, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.8 y=97.1
# Center: (497, 188), Servo : (95.8, 97.1), PID : (-5.8, -7.1000000000000005)
#
# 0: 384x640 1 face, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.8 y=98.1
# Center: (517, 190), Servo : (96.8, 98.1), PID : (-6.800000000000001, -8.100000000000001)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.7 y=98.2
# Center: (533, 207), Servo : (96.7, 98.2), PID : (-6.7, -8.200000000000001)
#
# 0: 384x640 1 face, 36.9ms
# Speed: 3.1ms preprocess, 36.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.6 y=99.2
# Center: (571, 221), Servo : (96.6, 99.2), PID : (-6.6000000000000005, -9.2)
#
# 0: 384x640 1 face, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.2 y=100.0
# Center: (576, 218), Servo : (97.2, 100.0), PID : (-7.2, -10.0)
#
# 0: 384x640 1 face, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.6 y=100.8
# Center: (575, 227), Servo : (97.6, 100.8), PID : (-7.6000000000000005, -10.8)
#
# 0: 384x640 1 face, 38.5ms
# Speed: 2.0ms preprocess, 38.5ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.0 y=101.6
# Center: (599, 239), Servo : (98.0, 101.6), PID : (-8.0, -11.600000000000001)
#
# 0: 384x640 1 face, 38.6ms
# Speed: 3.0ms preprocess, 38.6ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.4 y=102.4
# Center: (594, 239), Servo : (98.4, 102.4), PID : (-8.4, -12.4)
#
# 0: 384x640 1 face, 36.1ms
# Speed: 2.0ms preprocess, 36.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.0 y=103.2
# Center: (614, 233), Servo : (97.0, 103.2), PID : (-7.0, -13.200000000000001)
#
# 0: 384x640 1 face, 38.0ms
# Speed: 6.0ms preprocess, 38.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=103.1
# Center: (618, 261), Servo : (97.4, 103.1), PID : (-7.4, -13.100000000000001)
#
# 0: 384x640 1 face, 46.0ms
# Speed: 4.0ms preprocess, 46.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=103.9
# Center: (619, 274), Servo : (97.4, 103.9), PID : (-7.4, -13.9)
#
# 0: 384x640 1 face, 38.5ms
# Speed: 3.0ms preprocess, 38.5ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=104.5
# Center: (619, 274), Servo : (97.4, 104.5), PID : (-7.4, -14.5)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=105.1
# Center: (620, 274), Servo : (97.4, 105.1), PID : (-7.4, -15.100000000000001)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=104.8
# Center: (620, 282), Servo : (97.4, 104.8), PID : (-7.4, -14.8)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=105.4
# Center: (624, 305), Servo : (97.4, 105.4), PID : (-7.4, -15.4)
#
# 0: 384x640 1 face, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=105.8
# Center: (623, 306), Servo : (97.4, 105.8), PID : (-7.4, -15.8)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.2
# Center: (624, 305), Servo : (97.4, 106.2), PID : (-7.4, -16.200000000000003)
#
# 0: 384x640 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.6
# Center: (623, 306), Servo : (97.4, 106.6), PID : (-7.4, -16.6)
#
# 0: 384x640 1 face, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=107.0
# Center: (623, 310), Servo : (97.4, 107.0), PID : (-7.4, -17.0)
#
# 0: 384x640 1 face, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=107.4
# Center: (622, 314), Servo : (97.4, 107.4), PID : (-7.4, -17.400000000000002)
#
# 0: 384x640 1 face, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.0
# Center: (623, 344), Servo : (97.4, 106.0), PID : (-7.4, -16.000000000000004)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (622, 365), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 16.0ms
# Speed: 5.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (621, 362), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (621, 360), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (619, 363), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 18.0ms
# Speed: 2.5ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (619, 365), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (619, 371), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 37.1ms
# Speed: 3.0ms preprocess, 37.1ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (619, 366), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (620, 365), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (621, 362), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (622, 362), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (622, 363), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (620, 362), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (623, 360), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (625, 362), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (624, 367), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (624, 365), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (622, 362), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (621, 363), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (619, 354), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (619, 351), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (629, 333), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (637, 327), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (667, 329), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.4 y=106.4
# Center: (674, 326), Servo : (97.4, 106.4), PID : (-7.4, -16.400000000000002)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.6 y=106.4
# Center: (710, 330), Servo : (95.6, 106.4), PID : (-5.6, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=95.6 y=106.4
# Center: (719, 333), Servo : (95.6, 106.4), PID : (-5.6000000000000005, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.3 y=106.4
# Center: (746, 341), Servo : (94.3, 106.4), PID : (-4.3, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.8 y=106.4
# Center: (719, 340), Servo : (94.8, 106.4), PID : (-4.800000000000001, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.2 y=106.4
# Center: (717, 351), Servo : (94.2, 106.4), PID : (-4.2, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=93.8 y=106.4
# Center: (715, 354), Servo : (93.8, 106.4), PID : (-3.8000000000000007, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=92.5 y=106.4
# Center: (733, 361), Servo : (92.5, 106.4), PID : (-2.5, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=92.1 y=106.4
# Center: (733, 361), Servo : (92.1, 106.4), PID : (-2.1, -16.400000000000002)
#
# 0: 384x640 1 face, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=92.4 y=106.4
# Center: (690, 367), Servo : (92.4, 106.4), PID : (-2.4000000000000004, -16.400000000000002)
#
# 0: 384x640 1 face, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=91.8 y=106.4
# Center: (698, 368), Servo : (91.8, 106.4), PID : (-1.8000000000000003, -16.400000000000002)
#
# 0: 384x640 1 face, 35.5ms
# Speed: 4.0ms preprocess, 35.5ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=91.4 y=106.4
# Center: (715, 374), Servo : (91.4, 106.4), PID : (-1.4000000000000004, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=89.2 y=106.4
# Center: (772, 384), Servo : (89.2, 106.4), PID : (0.7999999999999999, -16.400000000000002)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=88.8 y=106.4
# Center: (790, 380), Servo : (88.8, 106.4), PID : (1.2, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=87.1 y=106.4
# Center: (831, 374), Servo : (87.1, 106.4), PID : (2.9000000000000004, -16.400000000000002)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=86.3 y=106.4
# Center: (835, 366), Servo : (86.3, 106.4), PID : (3.7, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=84.4 y=106.4
# Center: (842, 332), Servo : (84.4, 106.4), PID : (5.6000000000000005, -16.400000000000002)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=83.4 y=106.4
# Center: (841, 322), Servo : (83.4, 106.4), PID : (6.6, -16.400000000000002)
#
# 0: 384x640 1 face, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=84.0 y=108.2
# Center: (762, 299), Servo : (84.0, 108.2), PID : (6.0, -18.2)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=82.8 y=108.2
# Center: (766, 295), Servo : (82.8, 108.2), PID : (7.2, -18.2)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=82.0 y=108.6
# Center: (776, 296), Servo : (82.0, 108.6), PID : (8.0, -18.6)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=82.1 y=109.0
# Center: (757, 292), Servo : (82.1, 109.0), PID : (7.900000000000001, -19.0)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=82.2 y=109.4
# Center: (710, 302), Servo : (82.2, 109.4), PID : (7.8, -19.400000000000002)
#
# 0: 384x640 1 face, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.7 y=109.8
# Center: (721, 301), Servo : (80.7, 109.8), PID : (9.3, -19.8)
#
# 0: 384x640 1 face, 16.5ms
# Speed: 3.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.3 y=108.4
# Center: (735, 323), Servo : (80.3, 108.4), PID : (9.700000000000001, -18.400000000000002)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=79.7 y=108.8
# Center: (732, 323), Servo : (79.7, 108.8), PID : (10.3, -18.8)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=81.8 y=108.8
# Center: (666, 320), Servo : (81.8, 108.8), PID : (8.200000000000001, -18.8)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=81.2 y=110.6
# Center: (666, 318), Servo : (81.2, 110.6), PID : (8.8, -20.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=81.2 y=108.80000000000001
# Center: (672, 320), Servo : (81.2, 108.80000000000001), PID : (8.8, -18.800000000000004)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=81.2 y=111.0
# Center: (679, 319), Servo : (81.2, 111.0), PID : (8.8, -21.0)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=79.4 y=109.2
# Center: (703, 336), Servo : (79.4, 109.2), PID : (10.600000000000001, -19.200000000000003)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=79.4 y=109.6
# Center: (706, 376), Servo : (79.4, 109.6), PID : (10.600000000000001, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=79.0 y=109.6
# Center: (690, 382), Servo : (79.0, 109.6), PID : (11.0, -19.6)
#
# 0: 384x640 1 face, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.4 y=109.6
# Center: (668, 384), Servo : (80.4, 109.6), PID : (9.6, -19.6)
#
# 0: 384x640 1 face, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (669, 382), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (668, 384), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 45.5ms
# Speed: 4.0ms preprocess, 45.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (667, 384), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (665, 385), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 33.1ms
# Speed: 5.0ms preprocess, 33.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (662, 392), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (649, 395), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=80.0 y=109.6
# Center: (644, 389), Servo : (80.0, 109.6), PID : (10.0, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=81.8 y=109.6
# Center: (584, 400), Servo : (81.8, 109.6), PID : (8.200000000000001, -19.6)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=81.8 y=109.6
# Center: (562, 388), Servo : (81.8, 109.6), PID : (8.200000000000001, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=84.9 y=109.6
# Center: (466, 391), Servo : (84.9, 109.6), PID : (5.100000000000001, -19.6)
#
# 0: 384x640 1 face, 16.0ms
# Speed: 4.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=85.3 y=109.6
# Center: (446, 395), Servo : (85.3, 109.6), PID : (4.7, -19.6)
#
# 0: 384x640 1 face, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=89.0 y=109.6
# Center: (347, 399), Servo : (89.0, 109.6), PID : (1.0000000000000004, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=90.9 y=109.6
# Center: (307, 398), Servo : (90.9, 109.6), PID : (-0.8999999999999997, -19.6)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=92.5 y=109.6
# Center: (317, 396), Servo : (92.5, 109.6), PID : (-2.5, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=94.3 y=109.6
# Center: (292, 355), Servo : (94.3, 109.6), PID : (-4.3, -19.6)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=96.1 y=109.6
# Center: (307, 352), Servo : (96.1, 109.6), PID : (-6.1, -19.6)
#
# 0: 384x640 1 face, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.0 y=109.6
# Center: (336, 350), Servo : (97.0, 109.6), PID : (-7.0, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.8 y=109.6
# Center: (350, 357), Servo : (98.8, 109.6), PID : (-8.8, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.7 y=109.6
# Center: (442, 370), Servo : (97.7, 109.6), PID : (-7.700000000000001, -19.6)
#
# 0: 384x640 1 face, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.4 y=109.6
# Center: (491, 368), Servo : (98.4, 109.6), PID : (-8.400000000000002, -19.6)
#
# 0: 384x640 1 face, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.5 y=109.6
# Center: (521, 395), Servo : (98.5, 109.6), PID : (-8.5, -19.6)
#
# 0: 384x640 1 face, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=99.3 y=107.80000000000001
# Center: (548, 402), Servo : (99.3, 107.80000000000001), PID : (-9.3, -17.800000000000004)
#
# 0: 384x640 1 face, 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=99.0 y=109.6
# Center: (571, 388), Servo : (99.0, 109.6), PID : (-9.000000000000002, -19.6)
#
# 0: 384x640 1 face, 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=97.8 y=109.2
# Center: (612, 358), Servo : (97.8, 109.2), PID : (-7.800000000000001, -19.200000000000003)
#
# 0: 384x640 1 face, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.2 y=109.2
# Center: (609, 362), Servo : (98.2, 109.2), PID : (-8.200000000000001, -19.200000000000003)
#
# 0: 384x640 1 face, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Sent: x=98.2 y=109.2
# Center: (607, 380), Servo : (98.2, 109.2), PID : (-8.200000000000001, -19.200000000000003)
